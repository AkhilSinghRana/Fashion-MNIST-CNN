# %% [markdown]
# # CNN approach for fashion-MNIST
#
# This notebook shows different approaches to solve FashionMNIST problem.

# %% [markdown]
# #### Required data
# You can find the dataset and further informations at Zalando:
# - https://github.com/zalandoresearch/fashion-mnist

# %% [markdown]
# _______

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.1.0

# %%
#Import options from options.py needed for dataloading and generating models
import sys, os

# %run ../code/options.py
# %run ../code/util/dataLoader.py

import sys; sys.argv=['']; del sys
args = parseArguments()
print(args)
# Out:
# Call the script from train.py or main.py
# Namespace(batch_size=250, exp_name='Experiment_1', img_h=28, img_w=28, load_dir='saved_models', mode='train', model_arch='custom', num_aug=2, num_channels=1, num_classes=10, num_epochs=10, optimizer='Adam', save_dir='saved_models')

# %% [markdown]
# # Data Loading

# %%
# Generate Data Loader
dataloader = DataLoader(args)
(X_train, y_train), (X_test, y_test) = dataloader.generateData()

#Class mappign usefull for plotting
fashion_classes     = {0: 'T-shirt/top', 
                       1: 'Trouser', 
                       2: 'Pullover', 
                       3: 'Dress', 
                       4: 'Coat',
                       5: 'Sandal', 
                       6: 'Shirt', 
                       7: 'Sneaker', 
                       8: 'Bag', 
                       9: 'Ankle boot'}
# Out:
# Train Samples: 60000
# Test Samples: 10000

# %% [markdown]
# #### Plot random samples

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

idx = np.random.randint(len(X_train))
plt.imshow(np.squeeze(X_train[idx]), cmap='gray')
plt.axis('off')
plt.show()

print("Target:", fashion_classes[y_train[idx]])
# Out:
# Target: Sneaker

# %% [markdown]
# ### Data augmentation (optional)
# This method will increase the raw data by data augmentation of images. I just added rotation, horizontal flip and fill mode. Feel free to change these settings. These settings can be found in dataLoader.py
# Processing of raw images:
# - Scaling pixels between 0.0-1.0
# - Add augmentated images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Perform data Augmentation
X_train_shaped, y_train_shaped = dataloader.preprocess_data(
                                        X_train, y_train, 
                                        use_augmentation=True, 
                                        nb_of_augmentation=args.num_aug
                                        )
X_test_shaped, y_test_shaped   = dataloader.preprocess_data(X_test,  y_test)
# Out:
# Augmenting images...
# *Preprocessing completed: 180000 samples
#
# Augmenting images...
# *Preprocessing completed: 10000 samples

# %% [markdown]
# ### Model

# %% [markdown]
# #### Generate model now, all models ared defined isnide code/util/model.py

# %%
# %run ../code/util/model.py
args.model_arch="vgg_like"
model_obj = GenerateModel(args)
cnn_model = model_obj.cnn_model(modelArchitecture=args.model_arch) #Default Architecture is Custom finetuned

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1606144
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,679,082
# Trainable params: 1,677,674
# Non-trainable params: 1,408
# _________________________________________________________________

# %% [markdown]
# ### Run training
# Run training for number of iterations by random data for train/validation. The best model of each iteration will be saved as hdf5 checkpoint.

# %%
from sklearn.model_selection import train_test_split

args.num_epochs=80
histories = []

i=0
# Saving the best checkpoint for each iteration
filepath = "fashion_mnist-%i.hdf5" % i

X_train_, X_val_, y_train_, y_val_ = train_test_split(X_train_shaped, y_train_shaped,
                                                      test_size=0.2, random_state=42)

import time
start = time.time()
history = cnn_model.fit(
    X_train_, y_train_,
    batch_size=args.batch_size,
    epochs=args.num_epochs,
    verbose=1,
    validation_data=(X_val_, y_val_),
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
    ]
)
end = time.time()
print("Total time taken = ", end-start)
histories.append(history.history)
# Out:
# Train on 144000 samples, validate on 36000 samples
# Epoch 1/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.4328 - accuracy: 0.8487
# Epoch 00001: val_loss improved from inf to 0.38476, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 26s 181us/sample - loss: 0.4326 - accuracy: 0.8488 - val_loss: 0.3848 - val_accuracy: 0.8563
# Epoch 2/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.2763 - accuracy: 0.8990
# Epoch 00002: val_loss improved from 0.38476 to 0.25236, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 173us/sample - loss: 0.2763 - accuracy: 0.8990 - val_loss: 0.2524 - val_accuracy: 0.9081
# Epoch 3/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.2383 - accuracy: 0.9122
# Epoch 00003: val_loss improved from 0.25236 to 0.22401, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 169us/sample - loss: 0.2383 - accuracy: 0.9122 - val_loss: 0.2240 - val_accuracy: 0.9146
# Epoch 4/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.2126 - accuracy: 0.9222
# Epoch 00004: val_loss did not improve from 0.22401
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.2125 - accuracy: 0.9222 - val_loss: 0.2474 - val_accuracy: 0.9076
# Epoch 5/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1969 - accuracy: 0.9275
# Epoch 00005: val_loss improved from 0.22401 to 0.19536, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.1969 - accuracy: 0.9276 - val_loss: 0.1954 - val_accuracy: 0.9249
# Epoch 6/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.9335
# Epoch 00006: val_loss did not improve from 0.19536
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.1810 - accuracy: 0.9335 - val_loss: 0.2194 - val_accuracy: 0.9201
# Epoch 7/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9373
# Epoch 00007: val_loss improved from 0.19536 to 0.16112, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 169us/sample - loss: 0.1692 - accuracy: 0.9373 - val_loss: 0.1611 - val_accuracy: 0.9418
# Epoch 8/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9418
# Epoch 00008: val_loss improved from 0.16112 to 0.14973, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 26s 181us/sample - loss: 0.1569 - accuracy: 0.9418 - val_loss: 0.1497 - val_accuracy: 0.9445
# Epoch 9/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9444
# Epoch 00009: val_loss improved from 0.14973 to 0.14332, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 26s 181us/sample - loss: 0.1489 - accuracy: 0.9444 - val_loss: 0.1433 - val_accuracy: 0.9467
# Epoch 10/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9480
# Epoch 00010: val_loss improved from 0.14332 to 0.13997, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 172us/sample - loss: 0.1382 - accuracy: 0.9480 - val_loss: 0.1400 - val_accuracy: 0.9496
# Epoch 11/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1314 - accuracy: 0.9511
# Epoch 00011: val_loss did not improve from 0.13997
# 144000/144000 [==============================] - 24s 165us/sample - loss: 0.1315 - accuracy: 0.9510 - val_loss: 0.1505 - val_accuracy: 0.9483
# Epoch 12/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1250 - accuracy: 0.9534
# Epoch 00012: val_loss improved from 0.13997 to 0.13788, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.1250 - accuracy: 0.9534 - val_loss: 0.1379 - val_accuracy: 0.9514
# Epoch 13/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9567
# Epoch 00013: val_loss improved from 0.13788 to 0.13414, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 165us/sample - loss: 0.1162 - accuracy: 0.9566 - val_loss: 0.1341 - val_accuracy: 0.9514
# Epoch 14/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9588
# Epoch 00014: val_loss improved from 0.13414 to 0.12505, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.1108 - accuracy: 0.9587 - val_loss: 0.1250 - val_accuracy: 0.9559
# Epoch 15/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9607
# Epoch 00015: val_loss improved from 0.12505 to 0.12155, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 170us/sample - loss: 0.1065 - accuracy: 0.9608 - val_loss: 0.1216 - val_accuracy: 0.9569
# Epoch 16/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.1009 - accuracy: 0.9626
# Epoch 00016: val_loss improved from 0.12155 to 0.12068, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 29s 198us/sample - loss: 0.1010 - accuracy: 0.9626 - val_loss: 0.1207 - val_accuracy: 0.9571
# Epoch 17/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9647
# Epoch 00017: val_loss did not improve from 0.12068
# 144000/144000 [==============================] - 25s 173us/sample - loss: 0.0949 - accuracy: 0.9647 - val_loss: 0.1228 - val_accuracy: 0.9563
# Epoch 18/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9655
# Epoch 00018: val_loss improved from 0.12068 to 0.11816, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 174us/sample - loss: 0.0921 - accuracy: 0.9655 - val_loss: 0.1182 - val_accuracy: 0.9595
# Epoch 19/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0903 - accuracy: 0.9665
# Epoch 00019: val_loss improved from 0.11816 to 0.11563, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.0902 - accuracy: 0.9665 - val_loss: 0.1156 - val_accuracy: 0.9607
# Epoch 20/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9679
# Epoch 00020: val_loss did not improve from 0.11563
# 144000/144000 [==============================] - 24s 165us/sample - loss: 0.0850 - accuracy: 0.9680 - val_loss: 0.1163 - val_accuracy: 0.9607
# Epoch 21/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9705
# Epoch 00021: val_loss improved from 0.11563 to 0.11247, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 173us/sample - loss: 0.0802 - accuracy: 0.9705 - val_loss: 0.1125 - val_accuracy: 0.9618
# Epoch 22/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.9710
# Epoch 00022: val_loss improved from 0.11247 to 0.11183, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.0773 - accuracy: 0.9710 - val_loss: 0.1118 - val_accuracy: 0.9628
# Epoch 23/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9719
# Epoch 00023: val_loss improved from 0.11183 to 0.11085, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.0752 - accuracy: 0.9719 - val_loss: 0.1108 - val_accuracy: 0.9614
# Epoch 24/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0740 - accuracy: 0.9726
# Epoch 00024: val_loss did not improve from 0.11085
# 144000/144000 [==============================] - 25s 173us/sample - loss: 0.0740 - accuracy: 0.9726 - val_loss: 0.1148 - val_accuracy: 0.9617
# Epoch 25/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0713 - accuracy: 0.9738
# Epoch 00025: val_loss did not improve from 0.11085
# 144000/144000 [==============================] - 25s 175us/sample - loss: 0.0714 - accuracy: 0.9737 - val_loss: 0.1152 - val_accuracy: 0.9617
# Epoch 26/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9750
# Epoch 00026: val_loss did not improve from 0.11085
# 144000/144000 [==============================] - 25s 172us/sample - loss: 0.0670 - accuracy: 0.9750 - val_loss: 0.1145 - val_accuracy: 0.9622
# Epoch 27/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9748
# Epoch 00027: val_loss improved from 0.11085 to 0.10820, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 169us/sample - loss: 0.0680 - accuracy: 0.9748 - val_loss: 0.1082 - val_accuracy: 0.9642
# Epoch 28/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0635 - accuracy: 0.9763
# Epoch 00028: val_loss did not improve from 0.10820
# 144000/144000 [==============================] - 24s 168us/sample - loss: 0.0635 - accuracy: 0.9764 - val_loss: 0.1110 - val_accuracy: 0.9647
# Epoch 29/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0615 - accuracy: 0.9772
# Epoch 00029: val_loss improved from 0.10820 to 0.10724, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.0615 - accuracy: 0.9772 - val_loss: 0.1072 - val_accuracy: 0.9659
# Epoch 30/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0593 - accuracy: 0.9782
# Epoch 00030: val_loss improved from 0.10724 to 0.10648, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 170us/sample - loss: 0.0593 - accuracy: 0.9782 - val_loss: 0.1065 - val_accuracy: 0.9669
# Epoch 31/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9775
# Epoch 00031: val_loss improved from 0.10648 to 0.10523, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 25s 174us/sample - loss: 0.0603 - accuracy: 0.9775 - val_loss: 0.1052 - val_accuracy: 0.9672
# Epoch 32/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9786
# Epoch 00032: val_loss did not improve from 0.10523
# 144000/144000 [==============================] - 25s 175us/sample - loss: 0.0578 - accuracy: 0.9786 - val_loss: 0.1093 - val_accuracy: 0.9646
# Epoch 33/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9799
# Epoch 00033: val_loss did not improve from 0.10523
# 144000/144000 [==============================] - 24s 170us/sample - loss: 0.0549 - accuracy: 0.9799 - val_loss: 0.1124 - val_accuracy: 0.9654
# Epoch 34/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9803
# Epoch 00034: val_loss did not improve from 0.10523
# 144000/144000 [==============================] - 24s 165us/sample - loss: 0.0549 - accuracy: 0.9803 - val_loss: 0.1077 - val_accuracy: 0.9674
# Epoch 35/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9795
# Epoch 00035: val_loss improved from 0.10523 to 0.10376, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 164us/sample - loss: 0.0545 - accuracy: 0.9795 - val_loss: 0.1038 - val_accuracy: 0.9676
# Epoch 36/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9810
# Epoch 00036: val_loss did not improve from 0.10376
# 144000/144000 [==============================] - 24s 164us/sample - loss: 0.0528 - accuracy: 0.9810 - val_loss: 0.1043 - val_accuracy: 0.9668
# Epoch 37/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9819
# Epoch 00037: val_loss did not improve from 0.10376
# 144000/144000 [==============================] - 24s 166us/sample - loss: 0.0497 - accuracy: 0.9819 - val_loss: 0.1113 - val_accuracy: 0.9663
# Epoch 38/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0487 - accuracy: 0.9822
# Epoch 00038: val_loss did not improve from 0.10376
# 144000/144000 [==============================] - 24s 165us/sample - loss: 0.0487 - accuracy: 0.9822 - val_loss: 0.1040 - val_accuracy: 0.9691
# Epoch 39/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9819
# Epoch 00039: val_loss did not improve from 0.10376
# 144000/144000 [==============================] - 24s 164us/sample - loss: 0.0491 - accuracy: 0.9819 - val_loss: 0.1052 - val_accuracy: 0.9684
# Epoch 40/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9821
# Epoch 00040: val_loss did not improve from 0.10376
# 144000/144000 [==============================] - 24s 163us/sample - loss: 0.0485 - accuracy: 0.9821 - val_loss: 0.1150 - val_accuracy: 0.9673
# Epoch 41/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9825
# Epoch 00041: val_loss improved from 0.10376 to 0.10282, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 163us/sample - loss: 0.0472 - accuracy: 0.9825 - val_loss: 0.1028 - val_accuracy: 0.9682
# Epoch 42/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9830
# Epoch 00042: val_loss improved from 0.10282 to 0.09841, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 24s 166us/sample - loss: 0.0463 - accuracy: 0.9830 - val_loss: 0.0984 - val_accuracy: 0.9707
# Epoch 43/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9835
# Epoch 00043: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.0448 - accuracy: 0.9835 - val_loss: 0.1049 - val_accuracy: 0.9693
# Epoch 44/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9838
# Epoch 00044: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 168us/sample - loss: 0.0440 - accuracy: 0.9839 - val_loss: 0.1003 - val_accuracy: 0.9705
# Epoch 45/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9843
# Epoch 00045: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 164us/sample - loss: 0.0418 - accuracy: 0.9843 - val_loss: 0.1034 - val_accuracy: 0.9704
# Epoch 46/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9847
# Epoch 00046: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.0427 - accuracy: 0.9847 - val_loss: 0.1155 - val_accuracy: 0.9682
# Epoch 47/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9844
# Epoch 00047: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 166us/sample - loss: 0.0420 - accuracy: 0.9844 - val_loss: 0.1027 - val_accuracy: 0.9706
# Epoch 48/80
# 143500/144000 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9851
# Epoch 00048: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 168us/sample - loss: 0.0414 - accuracy: 0.9851 - val_loss: 0.1066 - val_accuracy: 0.9700
# Epoch 49/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0412 - accuracy: 0.9853
# Epoch 00049: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 25s 171us/sample - loss: 0.0412 - accuracy: 0.9853 - val_loss: 0.1097 - val_accuracy: 0.9684
# Epoch 50/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0408 - accuracy: 0.9853
# Epoch 00050: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 167us/sample - loss: 0.0408 - accuracy: 0.9853 - val_loss: 0.1035 - val_accuracy: 0.9700
# Epoch 51/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9856
# Epoch 00051: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 24s 164us/sample - loss: 0.0391 - accuracy: 0.9856 - val_loss: 0.1076 - val_accuracy: 0.9693
# Epoch 52/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9862
# Epoch 00052: val_loss did not improve from 0.09841
# 144000/144000 [==============================] - 32s 219us/sample - loss: 0.0380 - accuracy: 0.9862 - val_loss: 0.1101 - val_accuracy: 0.9678
# Epoch 53/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9861
# Epoch 00053: val_loss improved from 0.09841 to 0.09819, saving model to fashion_mnist-0.hdf5
# 144000/144000 [==============================] - 32s 224us/sample - loss: 0.0379 - accuracy: 0.9861 - val_loss: 0.0982 - val_accuracy: 0.9720
# Epoch 54/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9863
# Epoch 00054: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 224us/sample - loss: 0.0370 - accuracy: 0.9863 - val_loss: 0.1075 - val_accuracy: 0.9706
# Epoch 55/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9866
# Epoch 00055: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 223us/sample - loss: 0.0369 - accuracy: 0.9866 - val_loss: 0.1088 - val_accuracy: 0.9694
# Epoch 56/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9864
# Epoch 00056: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 229us/sample - loss: 0.0379 - accuracy: 0.9864 - val_loss: 0.1070 - val_accuracy: 0.9708
# Epoch 57/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9873
# Epoch 00057: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 222us/sample - loss: 0.0348 - accuracy: 0.9873 - val_loss: 0.1046 - val_accuracy: 0.9721
# Epoch 58/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9872
# Epoch 00058: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 225us/sample - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.1292 - val_accuracy: 0.9643
# Epoch 59/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9868
# Epoch 00059: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 223us/sample - loss: 0.0367 - accuracy: 0.9868 - val_loss: 0.1044 - val_accuracy: 0.9717
# Epoch 60/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9871
# Epoch 00060: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 222us/sample - loss: 0.0349 - accuracy: 0.9871 - val_loss: 0.1016 - val_accuracy: 0.9716
# Epoch 61/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9878
# Epoch 00061: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 224us/sample - loss: 0.0336 - accuracy: 0.9878 - val_loss: 0.1029 - val_accuracy: 0.9722
# Epoch 62/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9873
# Epoch 00062: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 222us/sample - loss: 0.0344 - accuracy: 0.9873 - val_loss: 0.1072 - val_accuracy: 0.9701
# Epoch 63/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9875
# Epoch 00063: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 229us/sample - loss: 0.0347 - accuracy: 0.9875 - val_loss: 0.1042 - val_accuracy: 0.9716
# Epoch 64/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0336 - accuracy: 0.9875
# Epoch 00064: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 227us/sample - loss: 0.0336 - accuracy: 0.9875 - val_loss: 0.1081 - val_accuracy: 0.9724
# Epoch 65/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9880
# Epoch 00065: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 228us/sample - loss: 0.0337 - accuracy: 0.9880 - val_loss: 0.1062 - val_accuracy: 0.9715
# Epoch 66/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9879
# Epoch 00066: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 224us/sample - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.1056 - val_accuracy: 0.9711
# Epoch 67/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9883 ETA:
# Epoch 00067: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 219us/sample - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.1096 - val_accuracy: 0.9711
# Epoch 68/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9886
# Epoch 00068: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 228us/sample - loss: 0.0321 - accuracy: 0.9886 - val_loss: 0.1112 - val_accuracy: 0.9697
# Epoch 69/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 0.9893
# Epoch 00069: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 31s 214us/sample - loss: 0.0295 - accuracy: 0.9893 - val_loss: 0.1097 - val_accuracy: 0.9721
# Epoch 70/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9884
# Epoch 00070: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 31s 218us/sample - loss: 0.0314 - accuracy: 0.9884 - val_loss: 0.1085 - val_accuracy: 0.9717
# Epoch 71/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9892
# Epoch 00071: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 31s 219us/sample - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.1031 - val_accuracy: 0.9729
# Epoch 72/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9892
# Epoch 00072: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 219us/sample - loss: 0.0296 - accuracy: 0.9892 - val_loss: 0.1098 - val_accuracy: 0.9713
# Epoch 73/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9887
# Epoch 00073: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 221us/sample - loss: 0.0317 - accuracy: 0.9887 - val_loss: 0.1019 - val_accuracy: 0.9725
# Epoch 74/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9884
# Epoch 00074: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 227us/sample - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.1021 - val_accuracy: 0.9728
# Epoch 75/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9890
# Epoch 00075: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 225us/sample - loss: 0.0298 - accuracy: 0.9890 - val_loss: 0.1053 - val_accuracy: 0.9725
# Epoch 76/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9902
# Epoch 00076: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 227us/sample - loss: 0.0281 - accuracy: 0.9902 - val_loss: 0.1036 - val_accuracy: 0.9725
# Epoch 77/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9899
# Epoch 00077: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 224us/sample - loss: 0.0277 - accuracy: 0.9899 - val_loss: 0.1088 - val_accuracy: 0.9716
# Epoch 78/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9903
# Epoch 00078: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 226us/sample - loss: 0.0273 - accuracy: 0.9903 - val_loss: 0.1071 - val_accuracy: 0.9720
# Epoch 79/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9896
# Epoch 00079: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 33s 227us/sample - loss: 0.0289 - accuracy: 0.9896 - val_loss: 0.1090 - val_accuracy: 0.9726
# Epoch 80/80
# 143750/144000 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9895
# Epoch 00080: val_loss did not improve from 0.09819
# 144000/144000 [==============================] - 32s 222us/sample - loss: 0.0288 - accuracy: 0.9895 - val_loss: 0.1156 - val_accuracy: 0.9700
# Total time taken =  2180.654232740402

# %% [markdown]
# # Evaluation

# %% [markdown]
# #### Trainingscores for loss and accuracy for all checkpoints
# Please remind that checkpoints will be saved by minimum loss.

# %%
def get_avg(histories, his_key):
    tmp = []
    for history in histories:
        tmp.append(history[his_key][np.argmin(history['val_loss'])])
    return np.mean(tmp)
    
print('Training: \t%0.8f loss / %0.8f acc'   % (get_avg(histories,'loss'), get_avg(histories,'accuracy')))
print('Validation: \t%0.8f loss / %0.8f acc' % (get_avg(histories,'val_loss'), get_avg(histories,'val_accuracy')))
# Out:
# Training: 	0.03786545 loss / 0.98611808 acc
# Validation: 	0.09819190 loss / 0.97197223 acc

# %% [markdown]
# #### Loss / accuracy of all models on testset
# Determine loss and accuracy of all models.

# %%
test_loss = []
test_accs = []

for i in range(0,1):
    cnn_ = tf.keras.models.load_model("fashion_mnist-%i.hdf5" % i)
    
    score = cnn_.evaluate(X_test_shaped, y_test_shaped, verbose=0)
    test_loss.append(score[0])
    test_accs.append(score[1])
    
    print('Running final test with model %i: %0.4f loss / %0.4f acc' % (i,score[0],score[1]))
    
print('\nAverage loss / accuracy on testset: %0.4f loss / %0.5f acc' % (np.mean(test_loss),np.mean(test_accs)))
print('Standard deviation: (+-%0.4f) loss / (+-%0.4f) acc' % (np.std(test_loss),np.std(test_accs)))
# Out:
# Running final test with model 0: 0.2404 loss / 0.9487 acc
#
# Average loss / accuracy on testset: 0.2404 loss / 0.94870 acc
# Standard deviation: (+-0.0000) loss / (+-0.0000) acc

# %% [markdown]
# ##### Plotting accuracy and loss for each iteration

# %%
def plot_acc_loss(title, histories, key_acc, key_loss):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    
    # Accuracy
    ax1.set_title('Model accuracy (%s)' % title)
    names = []
    for i, model in enumerate(histories):
        ax1.plot(model[key_acc])
        ax1.set_xlabel('epoch')
        names.append('Model %i' % i)
        ax1.set_ylabel('accuracy')
    ax1.legend(names, loc='upper left')
    
    # Loss
    ax2.set_title('Model loss (%s)' % title)
    for model in histories:
        ax2.plot(model[key_loss])
        ax2.set_xlabel('epoch')
        ax2.set_ylabel('loss')
    ax2.legend(names, loc='upper right')
    fig.set_size_inches(20, 5)
    plt.show()

# %%
plot_acc_loss('training', histories, 'accuracy', 'loss')
plot_acc_loss('validation', histories, 'val_accuracy', 'val_loss')

# %% [markdown]
# ## Evaluation for one model

# %%
RUN = 0 # you can choose one of the different models trained above
#model = create_model()
cnn_model.load_weights("fashion_mnist-%i.hdf5" % RUN)

# %% [markdown]
# ##### Plotting accuracy and loss for one model

# %%
def plot_train_val(title, history):
    fig, (ax1, ax2) = plt.subplots(1, 2)

    # Accuracy
    ax1.set_title('Model accuracy - %s' % title)
    ax1.plot(history['accuracy'])
    ax1.plot(history['val_accuracy'])
    ax1.set_xlabel('epoch')
    ax1.set_ylabel('accuracy')
    ax1.legend(['train', 'validation'], loc='upper left')

    # Loss
    ax2.set_title('Model loss - %s' % title)
    ax2.plot(history['loss'])
    ax2.plot(history['val_loss'])
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('loss')
    ax2.legend(['train', 'validation'], loc='upper left')

    fig.set_size_inches(20, 5)
    plt.show()

# %%
plot_train_val('Model %i' % RUN, histories[RUN])

# %% [markdown]
# ##### Displaying results of random predictions

# %%
def plot_sample_predictions(classes, model, X_test, y_test):
    """
    This function displays images randomly and tries to predict the correct class
    """

    class_ = 0
    images_per_row = 5
    rows = len(classes) // images_per_row
    
    for i in range(rows):
        fig, axis = plt.subplots(1, images_per_row)

        for i, axis in enumerate(axis):
            
            elements = np.squeeze(np.argwhere(y_test==class_))
            random   = np.random.randint(len(elements))
            
            X = X_test[elements[random]]
            y = y_test[elements[random]]

            fig.set_size_inches(10, 20)
            
            x_reshape = X.reshape([1,args.img_h,args.img_w,args.num_channels])
            axis.text(0,32,'Predicted: {}'.format(classes[np.argmax(model.predict(x_reshape))]))
            axis.text(0,36,'Correct: {}'.format((classes)[y]))
            axis.imshow(np.squeeze(X), cmap='gray')
            axis.axis('off')
            class_ +=1
    plt.show()

# %%
plot_sample_predictions(list(fashion_classes.values()), cnn_model, X_test_shaped, y_test)

# %% [markdown]
# ##### Plotting confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, class_, title='Confusion matrix', cmap=plt.cm.Reds):
    """
    This function plots a confusion matrix
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(class_))
    plt.xticks(tick_marks, class_, rotation=90)
    plt.yticks(tick_marks, class_)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i,j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True labels')
    plt.xlabel('Predicted labels')
    plt.show()

# %%
predictions = cnn_model.predict_classes(X_test_shaped, verbose=0)
plot_confusion_matrix(confusion_matrix(y_test, predictions), list(fashion_classes.values()))

# %% [markdown]
# ##### Report of f1, precision and recall

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      1000
#            1       1.00      0.99      0.99      1000
#            2       0.93      0.93      0.93      1000
#            3       0.94      0.96      0.95      1000
#            4       0.91      0.93      0.92      1000
#            5       0.99      1.00      0.99      1000
#            6       0.86      0.82      0.84      1000
#            7       0.97      0.99      0.98      1000
#            8       0.99      0.99      0.99      1000
#            9       0.99      0.97      0.98      1000
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# ____________
# ____________
